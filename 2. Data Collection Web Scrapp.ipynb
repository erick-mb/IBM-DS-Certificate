# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/Falcon9_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
#   ## Objectives
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
# - Extract a Falcon 9 launch records HTML table from Wikipedia
# - Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (2023.5.7)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
# assign the response to a object
wiki = requests.get(static_url)

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(wiki.content)

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
soup.title
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables= soup.find_all('table')

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table.find_all('th',scope='col'))
# Out:
# [<th scope="col">Flight No.
# </th>, <th scope="col">Date andtime ()
# </th>, <th scope="col">
# </th>, <th scope="col">Launch site
# </th>, <th scope="col">Payload
# </th>, <th scope="col">Payload mass
# </th>, <th scope="col">Orbit
# </th>, <th scope="col">Customer
# </th>, <th scope="col">Launchoutcome
# </th>, <th scope="col">
# </th>]

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = [extract_column_from_header(col) for col in first_launch_table.find_all('th',scope='col') if extract_column_from_header(col) != '']

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch Site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0
#Extract each table
for table_number,table in enumerate(soup.find_all('table',"wikitable plainrowheaders collapsible")):
   # get table row 
    for rows in table.find_all("tr"):
        #check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            if rows.th.string:
                flight_number=rows.th.string.strip()
                flag=flight_number.isdigit()
        else:
            flag=False
        #get table element 
        row=rows.find_all('td')
        
        #if it is number save cells in a dictonary 
        if flag:
            extracted_row += 1
            # Flight Number value
            flight_number = int(flight_number)
            
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            launch_dict['Flight No.'].append(flight_number)
            print("Appended:", flight_number, "into dict")
            
            # Date value
            datatimelist=date_time(row[0])
            
            # TODO: Append the date into launch_dict with key `Date`
            date = datatimelist[0].strip(',')
            launch_dict['Date'].append(date)
            print("Appended:", date, "into dict")
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1]
            launch_dict['Time'].append(time)
            print("Appended:", time, "into dict")
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster`
            bv=booster_version(row[1])
            if not(bv):
                bv=row[1].a.string
            launch_dict['Version Booster'].append(bv)
            print("Appended:", bv, "into dict")
            
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = row[2].a.string
            launch_dict['Launch Site'].append(launch_site)
            print("Appended:", launch_site, "into dict")
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            launch_dict['Payload'].append(payload)
            print("Appended:",payload, "into dict")
            
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            launch_dict['Payload mass'].append(payload_mass)
            print("Appended:",payload_mass, "into dict")
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            launch_dict['Orbit'].append(orbit)
            print("Appended:",orbit, "into dict")
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            customer = row[6].a.string
            launch_dict['Customer'].append(customer)
            print("Appended:",customer, "into dict")
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            launch_dict['Launch outcome'].append(launch_outcome)
            print("Appended:",launch_outcome, "into dict")
            
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8])
            launch_dict['Booster landing'].append(booster_landing)
            print("Appended:",booster_landing, "into dict")
# Out:
# Appended: 1 into dict
# Appended: 4 June 2010 into dict
# Appended: 18:45 into dict
# Appended: F9 v1.0B0003.1 into dict
# Appended: CCAFS into dict
# Appended: Dragon Spacecraft Qualification Unit into dict
# Appended: 0 into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Failure into dict
# Appended: 2 into dict
# Appended: 8 December 2010 into dict
# Appended: 15:43 into dict
# Appended: F9 v1.0B0004.1 into dict
# Appended: CCAFS into dict
# Appended: Dragon into dict
# Appended: 0 into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success into dict
# Appended: Failure into dict
# Appended: 3 into dict
# Appended: 22 May 2012 into dict
# Appended: 07:44 into dict
# Appended: F9 v1.0B0005.1 into dict
# Appended: CCAFS into dict
# Appended: Dragon into dict
# Appended: 525 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success into dict
# Appended: No attempt
#  into dict
# Appended: 4 into dict
# Appended: 8 October 2012 into dict
# Appended: 00:35 into dict
# Appended: F9 v1.0B0006.1 into dict
# Appended: CCAFS into dict
# Appended: SpaceX CRS-1 into dict
# Appended: 4,700 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: No attempt into dict
# Appended: 5 into dict
# Appended: 1 March 2013 into dict
# Appended: 15:10 into dict
# Appended: F9 v1.0B0007.1 into dict
# Appended: CCAFS into dict
# Appended: SpaceX CRS-2 into dict
# Appended: 4,877 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: No attempt
#  into dict
# Appended: 6 into dict
# Appended: 29 September 2013 into dict
# Appended: 16:00 into dict
# Appended: F9 v1.1B1003 into dict
# Appended: VAFB into dict
# Appended: CASSIOPE into dict
# Appended: 500 kg into dict
# Appended: Polar orbit into dict
# Appended: MDA into dict
# Appended: Success into dict
# Appended: Uncontrolled into dict
# Appended: 7 into dict
# Appended: 3 December 2013 into dict
# Appended: 22:41 into dict
# Appended: F9 v1.1 into dict
# Appended: CCAFS into dict
# Appended: SES-8 into dict
# Appended: 3,170 kg into dict
# Appended: GTO into dict
# Appended: SES into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 8 into dict
# Appended: 6 January 2014 into dict
# Appended: 22:06 into dict
# Appended: F9 v1.1 into dict
# Appended: CCAFS into dict
# Appended: Thaicom 6 into dict
# Appended: 3,325 kg into dict
# Appended: GTO into dict
# Appended: Thaicom into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 9 into dict
# Appended: 18 April 2014 into dict
# Appended: 19:25 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: SpaceX CRS-3 into dict
# Appended: 2,296 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Controlled into dict
# Appended: 10 into dict
# Appended: 14 July 2014 into dict
# Appended: 15:15 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: Orbcomm-OG2 into dict
# Appended: 1,316 kg into dict
# Appended: LEO into dict
# Appended: Orbcomm into dict
# Appended: Success into dict
# Appended: Controlled into dict
# Appended: 11 into dict
# Appended: 5 August 2014 into dict
# Appended: 08:00 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: AsiaSat 8 into dict
# Appended: 4,535 kg into dict
# Appended: GTO into dict
# Appended: AsiaSat into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 12 into dict
# Appended: 7 September 2014 into dict
# Appended: 05:00 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: AsiaSat 6 into dict
# Appended: 4,428 kg into dict
# Appended: GTO into dict
# Appended: AsiaSat into dict
# Appended: Success into dict
# Appended: No attempt
#  into dict
# Appended: 13 into dict
# Appended: 21 September 2014 into dict
# Appended: 05:52 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: SpaceX CRS-4 into dict
# Appended: 2,216 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success into dict
# Appended: Uncontrolled into dict
# Appended: 14 into dict
# Appended: 10 January 2015 into dict
# Appended: 09:47 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: SpaceX CRS-5 into dict
# Appended: 2,395 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success into dict
# Appended: Failure  into dict
# Appended: 15 into dict
# Appended: 11 February 2015 into dict
# Appended: 23:03 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: DSCOVR into dict
# Appended: 570 kg into dict
# Appended: HEO into dict
# Appended: USAF into dict
# Appended: Success
#  into dict
# Appended: Controlled into dict
# Appended: 16 into dict
# Appended: 2 March 2015 into dict
# Appended: 03:50 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: ABS-3A into dict
# Appended: 4,159 kg into dict
# Appended: GTO into dict
# Appended: ABS into dict
# Appended: Success
#  into dict
# Appended: No attempt into dict
# Appended: 17 into dict
# Appended: 14 April 2015 into dict
# Appended: 20:10 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: SpaceX CRS-6 into dict
# Appended: 1,898 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Failure into dict
# Appended: 18 into dict
# Appended: 27 April 2015 into dict
# Appended: 23:03 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: TürkmenÄlem 52°E / MonacoSAT into dict
# Appended: 4,707 kg into dict
# Appended: GTO into dict
# Appended: None into dict
# Appended: Success
#  into dict
# Appended: No attempt into dict
# Appended: 19 into dict
# Appended: 28 June 2015 into dict
# Appended: 14:21 into dict
# Appended: F9 v1.1 into dict
# Appended: Cape Canaveral into dict
# Appended: SpaceX CRS-7 into dict
# Appended: 1,952 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Failure into dict
# Appended: Precluded into dict
# Appended: 20 into dict
# Appended: 22 December 2015 into dict
# Appended: 01:29 into dict
# Appended: F9 FT into dict
# Appended: Cape Canaveral into dict
# Appended: Orbcomm-OG2 into dict
# Appended: 2,034 kg into dict
# Appended: LEO into dict
# Appended: Orbcomm into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 21 into dict
# Appended: 17 January 2016 into dict
# Appended: 18:42 into dict
# Appended: F9 v1.1 into dict
# Appended: VAFB into dict
# Appended: Jason-3 into dict
# Appended: 553 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Failure into dict
# Appended: 22 into dict
# Appended: 4 March 2016 into dict
# Appended: 23:35 into dict
# Appended: F9 FT into dict
# Appended: Cape Canaveral into dict
# Appended: SES-9 into dict
# Appended: 5,271 kg into dict
# Appended: GTO into dict
# Appended: SES into dict
# Appended: Success
#  into dict
# Appended: Failure into dict
# Appended: 23 into dict
# Appended: 8 April 2016 into dict
# Appended: 20:43 into dict
# Appended: F9 FT into dict
# Appended: Cape Canaveral into dict
# Appended: SpaceX CRS-8 into dict
# Appended: 3,136 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 24 into dict
# Appended: 6 May 2016 into dict
# Appended: 05:21 into dict
# Appended: F9 FT into dict
# Appended: Cape Canaveral into dict
# Appended: JCSAT-14 into dict
# Appended: 4,696 kg into dict
# Appended: GTO into dict
# Appended: SKY Perfect JSAT Group into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 25 into dict
# Appended: 27 May 2016 into dict
# Appended: 21:39 into dict
# Appended: F9 FT into dict
# Appended: Cape Canaveral into dict
# Appended: Thaicom 8 into dict
# Appended: 3,100 kg into dict
# Appended: GTO into dict
# Appended: Thaicom into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 26 into dict
# Appended: 15 June 2016 into dict
# Appended: 14:29 into dict
# Appended: F9 FT into dict
# Appended: Cape Canaveral into dict
# Appended: ABS-2A into dict
# Appended: 3,600 kg into dict
# Appended: GTO into dict
# Appended: ABS into dict
# Appended: Success
#  into dict
# Appended: Failure into dict
# Appended: 27 into dict
# Appended: 18 July 2016 into dict
# Appended: 04:45 into dict
# Appended: F9 FT into dict
# Appended: Cape Canaveral into dict
# Appended: SpaceX CRS-9 into dict
# Appended: 2,257 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 28 into dict
# Appended: 14 August 2016 into dict
# Appended: 05:26 into dict
# Appended: F9 FT into dict
# Appended: Cape Canaveral into dict
# Appended: JCSAT-16 into dict
# Appended: 4,600 kg into dict
# Appended: GTO into dict
# Appended: SKY Perfect JSAT Group into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 29 into dict
# Appended: 14 January 2017 into dict
# Appended: 17:54 into dict
# Appended: F9 FT into dict
# Appended: VAFB into dict
# Appended: Iridium NEXT into dict
# Appended: 9,600 kg into dict
# Appended: Polar into dict
# Appended: Iridium Communications into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 30 into dict
# Appended: 19 February 2017 into dict
# Appended: 14:39 into dict
# Appended: F9 FT into dict
# Appended: KSC into dict
# Appended: SpaceX CRS-10 into dict
# Appended: 2,490 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 31 into dict
# Appended: 16 March 2017 into dict
# Appended: 06:00 into dict
# Appended: F9 FT into dict
# Appended: KSC into dict
# Appended: EchoStar 23 into dict
# Appended: 5,600 kg into dict
# Appended: GTO into dict
# Appended: EchoStar into dict
# Appended: Success
#  into dict
# Appended: No attempt into dict
# Appended: 32 into dict
# Appended: 30 March 2017 into dict
# Appended: 22:27 into dict
# Appended: F9 FT♺ into dict
# Appended: KSC into dict
# Appended: SES-10 into dict
# Appended: 5,300 kg into dict
# Appended: GTO into dict
# Appended: SES into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 33 into dict
# Appended: 1 May 2017 into dict
# Appended: 11:15 into dict
# Appended: F9 FT into dict
# Appended: KSC into dict
# Appended: NROL-76 into dict
# Appended: C into dict
# Appended: LEO into dict
# Appended: NRO into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 34 into dict
# Appended: 15 May 2017 into dict
# Appended: 23:21 into dict
# Appended: F9 FT into dict
# Appended: KSC into dict
# Appended: Inmarsat-5 F4 into dict
# Appended: 6,070 kg into dict
# Appended: GTO into dict
# Appended: Inmarsat into dict
# Appended: Success
#  into dict
# Appended: No attempt into dict
# Appended: 35 into dict
# Appended: 3 June 2017 into dict
# Appended: 21:07 into dict
# Appended: F9 FT into dict
# Appended: KSC into dict
# Appended: SpaceX CRS-11 into dict
# Appended: 2,708 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 36 into dict
# Appended: 23 June 2017 into dict
# Appended: 19:10 into dict
# Appended: F9 FTB1029.2 into dict
# Appended: KSC into dict
# Appended: BulgariaSat-1 into dict
# Appended: 3,669 kg into dict
# Appended: GTO into dict
# Appended: Bulsatcom into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 37 into dict
# Appended: 25 June 2017 into dict
# Appended: 20:25 into dict
# Appended: F9 FT into dict
# Appended: VAFB into dict
# Appended: Iridium NEXT into dict
# Appended: 9,600 kg into dict
# Appended: LEO into dict
# Appended: Iridium Communications into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 38 into dict
# Appended: 5 July 2017 into dict
# Appended: 23:38 into dict
# Appended: F9 FT into dict
# Appended: KSC into dict
# Appended: Intelsat 35e into dict
# Appended: 6,761 kg into dict
# Appended: GTO into dict
# Appended: Intelsat into dict
# Appended: Success
#  into dict
# Appended: No attempt into dict
# Appended: 39 into dict
# Appended: 14 August 2017 into dict
# Appended: 16:31 into dict
# Appended: F9 B4 into dict
# Appended: KSC into dict
# Appended: SpaceX CRS-12 into dict
# Appended: 3,310 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 40 into dict
# Appended: 24 August 2017 into dict
# Appended: 18:51 into dict
# Appended: F9 FT into dict
# Appended: VAFB into dict
# Appended: Formosat-5 into dict
# Appended: 475 kg into dict
# Appended: SSO into dict
# Appended: NSPO into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 41 into dict
# Appended: 7 September 2017 into dict
# Appended: 14:00 into dict
# Appended: F9 B4 into dict
# Appended: KSC into dict
# Appended: Boeing X-37B into dict
# Appended: 4,990 kg into dict
# Appended: LEO into dict
# Appended: USAF into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 42 into dict
# Appended: 9 October 2017 into dict
# Appended: 12:37 into dict
# Appended: F9 B4 into dict
# Appended: VAFB into dict
# Appended: Iridium NEXT into dict
# Appended: 9,600 kg into dict
# Appended: Polar into dict
# Appended: Iridium Communications into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 43 into dict
# Appended: 11 October 2017 into dict
# Appended: 22:53:00 into dict
# Appended: F9 FTB1031.2 into dict
# Appended: KSC into dict
# Appended: SES-11 into dict
# Appended: 5,200 kg into dict
# Appended: GTO into dict
# Appended: SES S.A. into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 44 into dict
# Appended: 30 October 2017 into dict
# Appended: 19:34 into dict
# Appended: F9 B4 into dict
# Appended: KSC into dict
# Appended: Koreasat 5A into dict
# Appended: 3,500 kg into dict
# Appended: GTO into dict
# Appended: KT Corporation into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 45 into dict
# Appended: 15 December 2017 into dict
# Appended: 15:36 into dict
# Appended: F9 FTB1035.2 into dict
# Appended: Cape Canaveral into dict
# Appended: SpaceX CRS-13 into dict
# Appended: 2,205 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 46 into dict
# Appended: 23 December 2017 into dict
# Appended: 01:27 into dict
# Appended: F9 FTB1036.2 into dict
# Appended: VAFB into dict
# Appended: Iridium NEXT into dict
# Appended: 9,600 kg into dict
# Appended: Polar into dict
# Appended: Iridium Communications into dict
# Appended: Success into dict
# Appended: Controlled into dict
# Appended: 47 into dict
# Appended: 8 January 2018 into dict
# Appended: 01:00 into dict
# Appended: F9 B4 into dict
# Appended: CCAFS into dict
# Appended: Zuma into dict
# Appended: C into dict
# Appended: LEO into dict
# Appended: Northrop Grumman into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 48 into dict
# Appended: 31 January 2018 into dict
# Appended: 21:25 into dict
# Appended: F9 FTB1032.2 into dict
# Appended: CCAFS into dict
# Appended: GovSat-1 into dict
# Appended: 4,230 kg into dict
# Appended: GTO into dict
# Appended: SES into dict
# Appended: Success into dict
# Appended: Controlled into dict
# Appended: 49 into dict
# Appended: 22 February 2018 into dict
# Appended: 14:17 into dict
# Appended: F9 FTB1038.2 into dict
# Appended: VAFB into dict
# Appended: Paz into dict
# Appended: 2,150 kg into dict
# Appended: SSO into dict
# Appended: Hisdesat into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 50 into dict
# Appended: 6 March 2018 into dict
# Appended: 05:33 into dict
# Appended: F9 B4 into dict
# Appended: CCAFS into dict
# Appended: Hispasat 30W-6 into dict
# Appended: 6,092 kg into dict
# Appended: GTO into dict
# Appended: Hispasat into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 51 into dict
# Appended: 30 March 2018 into dict
# Appended: 14:14 into dict
# Appended: F9 B4B1041.2 into dict
# Appended: VAFB into dict
# Appended: Iridium NEXT into dict
# Appended: 9,600 kg into dict
# Appended: Polar into dict
# Appended: Iridium Communications into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 52 into dict
# Appended: 2 April 2018 into dict
# Appended: 20:30 into dict
# Appended: F9 B4B1039.2 into dict
# Appended: CCAFS into dict
# Appended: SpaceX CRS-14 into dict
# Appended: 2,647 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 53 into dict
# Appended: 18 April 2018 into dict
# Appended: 22:51 into dict
# Appended: F9 B4 into dict
# Appended: CCAFS into dict
# Appended: Transiting Exoplanet Survey Satellite into dict
# Appended: 362 kg into dict
# Appended: HEO into dict
# Appended: NASA into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 54 into dict
# Appended: 11 May 2018 into dict
# Appended: 20:14 into dict
# Appended: F9 B5B1046.1 into dict
# Appended: KSC into dict
# Appended: Bangabandhu-1 into dict
# Appended: 3,600 kg into dict
# Appended: GTO into dict
# Appended: Thales-Alenia into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 55 into dict
# Appended: 22 May 2018 into dict
# Appended: 19:47 into dict
# Appended: F9 B4B1043.2 into dict
# Appended: VAFB into dict
# Appended: Iridium NEXT into dict
# Appended: 6,460 kg into dict
# Appended: Polar into dict
# Appended: Iridium Communications into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 56 into dict
# Appended: 4 June 2018 into dict
# Appended: 04:45 into dict
# Appended: F9 B4B1040.2 into dict
# Appended: CCAFS into dict
# Appended: SES-12 into dict
# Appended: 5,384 kg into dict
# Appended: GTO into dict
# Appended: SES into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 57 into dict
# Appended: 29 June 2018 into dict
# Appended: 09:42 into dict
# Appended: F9 B4B1045.2 into dict
# Appended: CCAFS into dict
# Appended: SpaceX CRS-15 into dict
# Appended: 2,697 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 58 into dict
# Appended: 22 July 2018 into dict
# Appended: 05:50 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: Telstar 19V into dict
# Appended: 7,075 kg into dict
# Appended: GTO into dict
# Appended: Telesat into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 59 into dict
# Appended: 25 July 2018 into dict
# Appended: 11:39 into dict
# Appended: F9 B5B1048 into dict
# Appended: VAFB into dict
# Appended: Iridium NEXT into dict
# Appended: 9,600 kg into dict
# Appended: Polar into dict
# Appended: Iridium Communications into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 60 into dict
# Appended: 7 August 2018 into dict
# Appended: 05:18 into dict
# Appended: F9 B5B1046.2 into dict
# Appended: CCAFS into dict
# Appended: Merah Putih into dict
# Appended: 5,800 kg into dict
# Appended: GTO into dict
# Appended: Telkom Indonesia into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 61 into dict
# Appended: 10 September 2018 into dict
# Appended: 04:45 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: Telstar 18V into dict
# Appended: 7,060 kg into dict
# Appended: GTO into dict
# Appended: Telesat into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 62 into dict
# Appended: 8 October 2018 into dict
# Appended: 02:22 into dict
# Appended: F9 B5B1048.2 into dict
# Appended: VAFB into dict
# Appended: SAOCOM 1A into dict
# Appended: 3,000 kg into dict
# Appended: SSO into dict
# Appended: CONAE into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 63 into dict
# Appended: 15 November 2018 into dict
# Appended: 20:46 into dict
# Appended: F9 B5B1047.2 into dict
# Appended: KSC into dict
# Appended: Es'hail 2 into dict
# Appended: 5,300 kg into dict
# Appended: GTO into dict
# Appended: Es'hailSat into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 64 into dict
# Appended: 3 December 2018 into dict
# Appended: 18:34:05 into dict
# Appended: F9 B5B1046.3 into dict
# Appended: VAFB into dict
# Appended: SSO-A into dict
# Appended: ~4,000 kg into dict
# Appended: SSO into dict
# Appended: Spaceflight Industries into dict
# Appended: Success into dict
# Appended: Success into dict
# Appended: 65 into dict
# Appended: 5 December 2018 into dict
# Appended: 18:16 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: SpaceX CRS-16 into dict
# Appended: 2,500 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Failure into dict
# Appended: 66 into dict
# Appended: 23 December 2018 into dict
# Appended: 13:51 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: GPS III into dict
# Appended: 4,400 kg into dict
# Appended: MEO into dict
# Appended: USAF into dict
# Appended: Success into dict
# Appended: No attempt into dict
# Appended: 67 into dict
# Appended: 11 January 2019 into dict
# Appended: 15:31 into dict
# Appended: F9 B5B1049.2 into dict
# Appended: VAFB into dict
# Appended: Iridium NEXT into dict
# Appended: 9,600 kg into dict
# Appended: Polar into dict
# Appended: Iridium Communications into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 68 into dict
# Appended: 22 February 2019 into dict
# Appended: 01:45 into dict
# Appended: F9 B5B1048.3 into dict
# Appended: CCAFS into dict
# Appended: Nusantara Satu into dict
# Appended: 4,850 kg into dict
# Appended: GTO into dict
# Appended: PSN into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 69 into dict
# Appended: 2 March 2019 into dict
# Appended: 07:49 into dict
# Appended: F9 B5[268] into dict
# Appended: KSC into dict
# Appended: Crew Dragon Demo-1 into dict
# Appended: 12,055 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 70 into dict
# Appended: 4 May 2019 into dict
# Appended: 06:48 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: SpaceX CRS-17 into dict
# Appended: 2,495 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 71 into dict
# Appended: 24 May 2019 into dict
# Appended: 02:30 into dict
# Appended: F9 B5B1049.3 into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: 13,620 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 72 into dict
# Appended: 12 June 2019 into dict
# Appended: 14:17 into dict
# Appended: F9 B5B1051.2 into dict
# Appended: VAFB into dict
# Appended: RADARSAT Constellation into dict
# Appended: 4,200 kg into dict
# Appended: SSO into dict
# Appended: Canadian Space Agency into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 73 into dict
# Appended: 25 July 2019 into dict
# Appended: 22:01 into dict
# Appended: F9 B5B1056.2 into dict
# Appended: CCAFS into dict
# Appended: SpaceX CRS-18 into dict
# Appended: 2,268 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 74 into dict
# Appended: 6 August 2019 into dict
# Appended: 23:23 into dict
# Appended: F9 B5B1047.3 into dict
# Appended: CCAFS into dict
# Appended: AMOS-17 into dict
# Appended: 6,500 kg into dict
# Appended: GTO into dict
# Appended: Spacecom into dict
# Appended: Success
#  into dict
# Appended: No attempt into dict
# Appended: 75 into dict
# Appended: 11 November 2019 into dict
# Appended: 14:56 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 76 into dict
# Appended: 5 December 2019 into dict
# Appended: 17:29 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: SpaceX CRS-19 into dict
# Appended: 2,617 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 77 into dict
# Appended: 17 December 2019 into dict
# Appended: 00:10 into dict
# Appended: F9 B5B1056.3 into dict
# Appended: CCAFS into dict
# Appended: JCSat-18 into dict
# Appended: 6,956 kg into dict
# Appended: GTO into dict
# Appended: Sky Perfect JSAT into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 78 into dict
# Appended: 7 January 2020 into dict
# Appended: 02:19:21 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 79 into dict
# Appended: 19 January 2020 into dict
# Appended: 15:30 into dict
# Appended: F9 B5 into dict
# Appended: KSC into dict
# Appended: Crew Dragon in-flight abort test into dict
# Appended: 12,050 kg into dict
# Appended: Sub-orbital into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: No attempt
#  into dict
# Appended: 80 into dict
# Appended: 29 January 2020 into dict
# Appended: 14:07 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 81 into dict
# Appended: 17 February 2020 into dict
# Appended: 15:05 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Failure into dict
# Appended: 82 into dict
# Appended: 7 March 2020 into dict
# Appended: 04:50 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: SpaceX CRS-20 into dict
# Appended: 1,977 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 83 into dict
# Appended: 18 March 2020 into dict
# Appended: 12:16 into dict
# Appended: F9 B5 into dict
# Appended: KSC into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Failure into dict
# Appended: 84 into dict
# Appended: 22 April 2020 into dict
# Appended: 19:30 into dict
# Appended: F9 B5 into dict
# Appended: KSC into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 85 into dict
# Appended: 30 May 2020 into dict
# Appended: 19:22 into dict
# Appended: F9 B5 into dict
# Appended: KSC into dict
# Appended: Crew Dragon Demo-2 into dict
# Appended: 12,530 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 86 into dict
# Appended: 4 June 2020 into dict
# Appended: 01:25 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 87 into dict
# Appended: 13 June 2020 into dict
# Appended: 09:21 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: 15,410 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 88 into dict
# Appended: 30 June 2020 into dict
# Appended: 20:10:46 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: GPS III into dict
# Appended: 4,311 kg into dict
# Appended: MEO into dict
# Appended: U.S. Space Force into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 89 into dict
# Appended: 20 July 2020 into dict
# Appended: 21:30 into dict
# Appended: F9 B5B1058.2 into dict
# Appended: CCAFS into dict
# Appended: ANASIS-II into dict
# Appended: 5,000–6,000 kg into dict
# Appended: GTO into dict
# Appended: Republic of Korea Army into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 90 into dict
# Appended: 7 August 2020 into dict
# Appended: 05:12 into dict
# Appended: F9 B5 into dict
# Appended: KSC into dict
# Appended: Starlink into dict
# Appended: 14,932 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 91 into dict
# Appended: 18 August 2020 into dict
# Appended: 14:31 into dict
# Appended: F9 B5B1049.6 into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: ~15,440 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 92 into dict
# Appended: 30 August 2020 into dict
# Appended: 23:18 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: SAOCOM 1B into dict
# Appended: 3,130 kg into dict
# Appended: SSO into dict
# Appended: CONAE into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 93 into dict
# Appended: 3 September 2020 into dict
# Appended: 12:46:14 into dict
# Appended: F9 B5B1060.2 into dict
# Appended: KSC into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 94 into dict
# Appended: 6 October 2020 into dict
# Appended: 11:29:34 into dict
# Appended: F9 B5B1058.3 into dict
# Appended: KSC into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 95 into dict
# Appended: 18 October 2020 into dict
# Appended: 12:25:57 into dict
# Appended: F9 B5B1051.6 into dict
# Appended: KSC into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 96 into dict
# Appended: 24 October 2020 into dict
# Appended: 15:31:34 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 97 into dict
# Appended: 5 November 2020 into dict
# Appended: 23:24:23 into dict
# Appended: F9 B5 into dict
# Appended: CCAFS into dict
# Appended: GPS III into dict
# Appended: 4,311 kg into dict
# Appended: MEO into dict
# Appended: USSF into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 98 into dict
# Appended: 16 November 2020 into dict
# Appended: 00:27 into dict
# Appended: F9 B5 into dict
# Appended: KSC into dict
# Appended: Crew-1 into dict
# Appended: ~12,500 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 99 into dict
# Appended: 21 November 2020 into dict
# Appended: 17:17:08 into dict
# Appended: F9 B5 into dict
# Appended: VAFB into dict
# Appended: Sentinel-6 Michael Freilich (Jason-CS A) into dict
# Appended: 1,192 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 100 into dict
# Appended: 25 November 2020 into dict
# Appended: 02:13 into dict
# Appended: F9 B5 ♺ into dict
# Appended: CCAFS into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 101 into dict
# Appended: 6 December 2020 into dict
# Appended: 16:17:08 into dict
# Appended: F9 B5 ♺ into dict
# Appended: KSC into dict
# Appended: SpaceX CRS-21 into dict
# Appended: 2,972 kg into dict
# Appended: LEO into dict
# Appended: NASA into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 102 into dict
# Appended: 13 December 2020 into dict
# Appended: 17:30:00 into dict
# Appended: F9 B5 ♺ into dict
# Appended: CCSFS into dict
# Appended: SXM-7 into dict
# Appended: 7,000 kg into dict
# Appended: GTO into dict
# Appended: Sirius XM into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 103 into dict
# Appended: 19 December 2020 into dict
# Appended: 14:00:00 into dict
# Appended: F9 B5 ♺ into dict
# Appended: KSC into dict
# Appended: NROL-108 into dict
# Appended: C into dict
# Appended: LEO into dict
# Appended: NRO into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 104 into dict
# Appended: 8 January 2021 into dict
# Appended: 02:15 into dict
# Appended: F9 B5 into dict
# Appended: CCSFS into dict
# Appended: Türksat 5A into dict
# Appended: 3,500 kg into dict
# Appended: GTO into dict
# Appended: Türksat into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 105 into dict
# Appended: 20 January 2021 into dict
# Appended: 13:02 into dict
# Appended: F9 B5B1051.8 into dict
# Appended: KSC into dict
# Appended: Starlink into dict
# Appended: 15,600 kg into dict
# Appended: LEO into dict
# Appended: SpaceX into dict
# Appended: Success
#  into dict
# Appended: Success into dict
# Appended: 106 into dict
# Appended: 24 January 2021 into dict
# Appended: 15:00 into dict
# Appended: F9 B5B1058.5 into dict
# Appended: CCSFS into dict
# Appended: Transporter-1 into dict
# Appended: ~5,000 kg into dict
# Appended: SSO into dict
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1549/1821368959.py in <module>
#      73             # Customer
#      74             # TODO: Append the customer into launch_dict with key `Customer`
# ---> 75             customer = row[6].a.string
#      76             launch_dict['Customer'].append(customer)
#      77             print("Appended:",customer, "into dict")
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df= pd.DataFrame({ key:pd.Series(value) for key, value in launch_dict.items() })
df
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
#      Flight No.  Launch site                               Payload  \
# 0             1          NaN  Dragon Spacecraft Qualification Unit
# 1             2          NaN                                Dragon
# 2             3          NaN                                Dragon
# 3             4          NaN                          SpaceX CRS-1
# 4             5          NaN                          SpaceX CRS-2
# ..          ...          ...                                   ...
# 101         102          NaN                                 SXM-7
# 102         103          NaN                              NROL-108
# 103         104          NaN                            Türksat 5A
# 104         105          NaN                              Starlink
# 105         106          NaN                         Transporter-1
#
#     Payload mass Orbit   Customer Launch outcome Launch Site Version Booster  \
# 0              0   LEO     SpaceX      Success\n       CCAFS  F9 v1.0B0003.1
# 1              0   LEO       NASA        Success       CCAFS  F9 v1.0B0004.1
# 2         525 kg   LEO       NASA        Success       CCAFS  F9 v1.0B0005.1
# 3       4,700 kg   LEO       NASA      Success\n       CCAFS  F9 v1.0B0006.1
# 4       4,877 kg   LEO       NASA      Success\n       CCAFS  F9 v1.0B0007.1
# ..           ...   ...        ...            ...         ...             ...
# 101     7,000 kg   GTO  Sirius XM      Success\n       CCSFS         F9 B5 ♺
# 102            C   LEO        NRO      Success\n         KSC         F9 B5 ♺
# 103     3,500 kg   GTO    Türksat      Success\n       CCSFS           F9 B5
# 104    15,600 kg   LEO     SpaceX      Success\n         KSC    F9 B5B1051.8
# 105    ~5,000 kg   SSO        NaN            NaN       CCSFS    F9 B5B1058.5
#
#     Booster landing              Date      Time
# 0           Failure       4 June 2010     18:45
# 1           Failure   8 December 2010     15:43
# 2      No attempt\n       22 May 2012     07:44
# 3        No attempt    8 October 2012     00:35
# 4      No attempt\n      1 March 2013     15:10
# ..              ...               ...       ...
# 101         Success  13 December 2020  17:30:00
# 102         Success  19 December 2020  14:00:00
# 103         Success    8 January 2021     02:15
# 104         Success   20 January 2021     13:02
# 105             NaN   24 January 2021     15:00
#
# [106 rows x 12 columns]

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/">Nayef Abou Tayoun</a>

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates           |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
